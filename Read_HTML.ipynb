# %% [markdown]
# <a href="https://colab.research.google.com/github/igsurf/Collab_ReadHTML/blob/main/Read_HTML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_html("https://wiki.ubuntu.com")[1];
df
# Out:
#                              0          1                 2  \
# 0  Released (Current & Stable)    Version  Release Schedule
# 1                 Xenial Xerus  16.04 LTS    April 21, 2016
# 2                Bionic Beaver  18.04 LTS    April 26, 2018
# 3                  Focal Fossa  20.04 LTS    April 23, 2020
# 4                Hirsute Hippo      21.04    April 22, 2021
# 5                 Impish Indri      21.10  October 14, 2021
# 6              Jammy Jellyfish  22.04 LTS    April 21, 2022
#
#                               3
# 0                  Support Date
# 1    Supported until April 2021
# 2    Supported until April 2023
# 3    Supported until April 2025
# 4  Supported until January 2022
# 5     Supported until July 2022
# 6     Supported until July 2027
